# %% [markdown]
# # PyQt Hello World
#
# [Source Link](https://www.pythontutorial.net/pyqt/pyqt-hello-world/)

# %%
# Creating a window

from PyQt6.QtWidgets import QApplication, QWidget


# create a QApplication
app = QApplication([])

# create the main window
window = QWidget(windowTitle='Hello World')
window.show()

# start the event loop
app.exec()
# Out:
# 0

# %% [markdown]
# To run the application, you use the python command:
# ```
# python [name of file].py
# ```

# %% [markdown]
# ## Explaining the code
# Works as an Object Orientated System
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Supporting command line argument & return code

# %%
import sys
from PyQt6.QtWidgets import QApplication, QWidget

# Create the QApplication with taking arguments
app = QApplication(sys.argv)

#Create the main window
window = QWidget(windowTitle="Hello World 2")
window.show()

#Start the event loop
sys.exit(app.exec())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\tprag\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:3513: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## Creating a Qt program template

# %%
import sys
from PyQt6.QtWidgets import QApplication, QWidget

class MainWindow(QWidget):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

        # set the window title
        self.setWindowTitle('Hello World')

        # show the window
        self.show()

if __name__ == '__main__':
    app = QApplication(sys.argv)

    # create the main window
    window = MainWindow()

    # start the event loop
    sys.exit(app.exec())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\tprag\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:3513: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
